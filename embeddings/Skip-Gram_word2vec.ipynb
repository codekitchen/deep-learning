# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:42, 742KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
int_words[:10]
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import math
import random

t = 1e-5
word_counts = Counter(int_words)
freqs = {word: (count / len(words)) for word, count in word_counts.items()}
probs = {word: (1 - math.sqrt(t / freqs[word])) for word in word_counts}

train_words = [word for word in int_words if probs[word] < random.random()]
print(len(words), len(train_words))
# Out:
# 16680599 4625359

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    window_size = random.randint(1, window_size)
    return words[max(0, idx-window_size):idx] + words[idx+1:min(idx+1+window_size,len(words))]

print(get_target("the quick brown fox jumped over the lazy dog".split(), 4))
# Out:
# ['quick', 'brown', 'fox', 'over', 'the', 'lazy']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, (None,))
    labels = tf.placeholder(tf.int32, (None,1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.get_variable("embedding", (n_vocab, n_embedding), initializer=tf.initializers.random_uniform(-1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs, name="embed_lookup") # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.get_variable("softmax_w", (n_vocab, n_embedding), initializer=tf.initializers.truncated_normal(0, 0.1)) # create softmax weight matrix here
    softmax_b = tf.get_variable("softmax_b", (n_vocab,), initializer=tf.initializers.constant(0)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab, partition_strategy="div", name="sampled_softmax_loss")
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6164 0.2083 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5985 0.1953 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4530 0.1969 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5317 0.2140 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4538 0.2257 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4803 0.2186 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5141 0.2196 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4823 0.1962 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4542 0.1937 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3467 0.1944 sec/batch
# Nearest to have: apl, crayfish, monody, stat, warren, gaits, dealings, function,
# Nearest to use: langton, nigger, fraternal, bbci, karlovac, meir, lica, lessing,
# Nearest to american: polymorphic, employee, concordant, cts, conflicts, target, universitet, beal,
# Nearest to up: supper, trilemma, stumble, escorial, yeo, datagram, communion, evidentiary,
# Nearest to would: tuition, probabilistic, paterson, supervision, floundered, gui, masai, accentuate,
# Nearest to if: samples, cunt, stifling, parse, xi, vitally, bustling, yielded,
# Nearest to when: thea, beneficial, multivariate, openly, lactam, cnbc, instead, physica,
# Nearest to about: skilling, uqbar, inhalation, sainte, relaxing, loach, photographic, haden,
# Nearest to older: blessed, yes, classicists, segal, unctad, port, linens, proposed,
# Nearest to governor: mumford, schmitt, apocalyptic, byproduct, assize, queens, afesd, motorized,
# Nearest to heavy: teamwork, trolley, versatility, livelihood, pubs, regolith, epiglottal, travail,
# Nearest to placed: russel, offbeat, belew, unprofessional, noticeable, suitcase, easter, disqualification,
# Nearest to joseph: planner, decomposition, vermin, rifles, grazia, sectioning, benefit, radiance,
# Nearest to discovered: harrisburg, jambalaya, taps, woodsman, encampments, blastoderm, stereotype, subsp,
# Nearest to quite: asch, gyatso, fdp, manichean, ho, nubians, outboard, devalued,
# Nearest to rise: metabolically, infighting, batasuna, picketing, chuang, naqada, odrade, supple,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4263 0.1957 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3387 0.1905 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3175 0.1900 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2106 0.1911 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1793 0.1913 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1762 0.1962 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0564 0.1967 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0525 0.1904 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9810 0.1912 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9844 0.1902 sec/batch
# Nearest to have: crayfish, apl, function, evenly, spectrum, fails, stat, dealings,
# Nearest to use: langton, com, ability, arrival, karlovac, fraternal, augmented, neither,
# Nearest to american: employee, occurring, target, polymorphic, conflicts, beal, geological, practice,
# Nearest to up: motor, escorial, apprehension, sex, supper, stumble, communion, xiongnu,
# Nearest to would: tuition, probabilistic, supervision, nation, surrounded, gui, paterson, nonexistent,
# Nearest to if: xi, samples, any, later, wider, man, vitally, merchant,
# Nearest to when: beneficial, instead, openly, multivariate, thea, variety, inhabitants, year,
# Nearest to about: photographic, suitable, episodes, skilling, uqbar, sainte, inhalation, whereas,
# Nearest to older: blessed, yes, proposed, port, canada, fifth, classicists, inquiries,
# Nearest to governor: apocalyptic, mumford, investments, greater, queens, schmitt, byproduct, cropped,
# Nearest to heavy: teamwork, trolley, regolith, yellow, seats, pubs, anderson, livelihood,
# Nearest to placed: noticeable, unprofessional, disqualification, russel, offbeat, conjugated, employee, navy,
# Nearest to joseph: planner, decomposition, benefit, vermin, machinery, rifles, grenada, radiance,
# Nearest to discovered: stereotype, describe, fullness, unprofessional, harrisburg, question, subsp, while,
# Nearest to quite: asch, be, gyatso, fdp, codify, mitral, manichean, yc,
# Nearest to rise: metabolically, batasuna, infighting, chuang, working, prehistoric, supple, presenting,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9242 0.1945 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9112 0.1905 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8834 0.1926 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8359 0.1920 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7885 0.1896 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8231 0.1915 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7980 0.1906 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7822 0.1894 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8041 0.1921 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7695 0.1905 sec/batch
# Nearest to have: crayfish, apl, dealings, evenly, spectrum, stat, warren, function,
# Nearest to use: langton, neither, karlovac, augmented, arrival, itv, deadwood, com,
# Nearest to american: occurring, employee, target, polymorphic, fearing, biblical, beal, conflicts,
# Nearest to up: supper, escorial, sex, communion, stumble, ceasefire, motor, yeo,
# Nearest to would: tuition, probabilistic, supervision, gui, nonexistent, betsy, paterson, allergy,
# Nearest to if: any, samples, vitally, yielded, man, xi, wider, simple,
# Nearest to when: beneficial, openly, thea, instead, multivariate, readily, intolerable, neck,
# Nearest to about: photographic, skilling, uqbar, suitable, yahoo, inhalation, summers, episodes,
# Nearest to older: blessed, yes, classicists, proposed, canada, fifth, exercised, marva,
# Nearest to governor: queens, mumford, apocalyptic, consular, investments, schmitt, takla, assize,
# Nearest to heavy: teamwork, trolley, seats, versatility, yellow, anderson, regolith, livelihood,
# Nearest to placed: unprofessional, russel, noticeable, disqualification, easter, seventeen, simplest, responded,
# Nearest to joseph: decomposition, planner, machinery, rifles, vermin, nbs, grenada, rulemaking,
# Nearest to discovered: stereotype, describe, harrisburg, fullness, unprofessional, migration, question, subsp,
# Nearest to quite: asch, be, fdp, manichean, gyatso, codify, ho, devalued,
# Nearest to rise: metabolically, batasuna, infighting, chuang, fledged, prehistoric, picketing, translucent,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7843 0.1944 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7649 0.1912 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7135 0.1891 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6874 0.1888 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7340 0.1908 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7229 0.1905 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6865 0.1891 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7210 0.1883 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6907 0.1883 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6666 0.1894 sec/batch
# Nearest to have: crayfish, apl, dealings, spectrum, install, stat, evenly, monody,
# Nearest to use: karlovac, langton, fraternal, augmented, itv, deadwood, ability, nigger,
# Nearest to american: actor, comedian, joe, nobel, prize, occurring, polymorphic, beal,
# Nearest to up: supper, stumble, ceasefire, escorial, communion, yeo, datagram, motor,
# Nearest to would: tuition, probabilistic, supervision, gui, nonexistent, betsy, paterson, floundered,
# Nearest to if: any, samples, vitally, simple, yielded, conversely, wider, stifling,
# Nearest to when: thea, openly, beneficial, intolerable, instead, multivariate, grey, readily,
# Nearest to about: skilling, uqbar, inhalation, photographic, adhere, yahoo, tasker, decadence,
# Nearest to older: blessed, yes, classicists, segal, switchover, unctad, counseling, marva,
# Nearest to governor: mumford, consular, assize, queens, schmitt, takla, apocalyptic, ncbi,
# Nearest to heavy: teamwork, trolley, regolith, versatility, livelihood, yellow, pubs, jacobites,
# Nearest to placed: russel, disqualification, unprofessional, noticeable, offbeat, easter, prepared, responded,
# Nearest to joseph: planner, decomposition, rifles, nbs, mineralogist, vermin, investing, thirteen,
# Nearest to discovered: stereotype, unprofessional, harrisburg, encampments, fullness, woodsman, asteroid, subsp,
# Nearest to quite: asch, be, manichean, uua, gyatso, fdp, ho, devalued,
# Nearest to rise: metabolically, infighting, batasuna, chuang, picketing, caucus, fledged, superhuman,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6599 0.1921 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6491 0.1882 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6323 0.1891 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6275 0.1894 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6388 0.1886 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6594 0.1881 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5794 0.1425 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5516 0.1909 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4880 0.1896 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5281 0.1896 sec/batch
# Nearest to have: apl, crayfish, spectrum, dealings, install, evenly, stat, germination,
# Nearest to use: karlovac, ability, kla, visible, interconnected, circuits, fraternal, nigger,
# Nearest to american: comedian, actor, nobel, prize, joe, patrick, rick, football,
# Nearest to up: supper, stumble, ceasefire, yeo, communion, castilian, escorial, trilemma,
# Nearest to would: tuition, probabilistic, gui, nonexistent, betsy, supervision, allergy, mannlicher,
# Nearest to if: any, samples, simple, vitally, conversely, convergence, yielded, wider,
# Nearest to when: thea, openly, beneficial, intolerable, cnbc, instead, multivariate, readily,
# Nearest to about: uqbar, skilling, inhalation, photographic, yahoo, loach, sainte, decadence,
# Nearest to older: blessed, yes, classicists, squeezes, marva, unctad, counseling, switchover,
# Nearest to governor: mumford, consular, assize, queens, weill, swimmer, tocqueville, louis,
# Nearest to heavy: teamwork, trolley, regolith, versatility, pubs, yellow, jacobites, oswaldo,
# Nearest to placed: russel, disqualification, unprofessional, responded, easter, countdown, offbeat, convicts,
# Nearest to joseph: planner, mineralogist, nbs, vsat, alexei, rifles, decomposition, vermin,
# Nearest to discovered: unprofessional, harrisburg, stereotype, asteroid, encampments, fullness, woodsman, deregulation,
# Nearest to quite: asch, be, manichean, uua, gyatso, peaks, fdp, mitral,
# Nearest to rise: metabolically, infighting, batasuna, picketing, chuang, caucus, fledged, superhuman,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5143 0.1914 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4651 0.1902 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4669 0.1901 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5000 0.1894 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4668 0.1899 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4536 0.1891 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4512 0.1883 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3942 0.1874 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4170 0.1884 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3923 0.1871 sec/batch
# Nearest to have: apl, crayfish, install, spectrum, dealings, evenly, monody, small,
# Nearest to use: karlovac, ability, circuits, integrated, components, interconnected, kla, is,
# Nearest to american: comedian, actor, joe, nobel, rick, prize, football, beal,
# Nearest to up: stumble, supper, trilemma, escorial, ceasefire, evidentiary, datagram, motor,
# Nearest to would: tuition, probabilistic, betsy, allergy, supervision, mannlicher, vetting, germline,
# Nearest to if: any, simple, samples, vitally, conversely, convergence, wider, elements,
# Nearest to when: beneficial, thea, openly, multivariate, intolerable, cnbc, disappearing, dangerous,
# Nearest to about: uqbar, skilling, inhalation, loach, photographic, ads, yahoo, decadence,
# Nearest to older: blessed, yes, squeezes, classicists, counseling, marva, unctad, kosar,
# Nearest to governor: consular, mumford, assize, queens, senate, crown, provinces, tocqueville,
# Nearest to heavy: trolley, teamwork, regolith, yellow, versatility, pubs, tetrahedron, oswaldo,
# Nearest to placed: russel, responded, disqualification, unprofessional, prepared, countdown, noticeable, easter,
# Nearest to joseph: planner, mineralogist, nbs, vsat, rome, vermin, wife, alexei,
# Nearest to discovered: unprofessional, encampments, asteroid, harrisburg, stereotype, hj, reverend, fullness,
# Nearest to quite: be, manichean, uua, asch, gyatso, mitral, ho, fdp,
# Nearest to rise: metabolically, picketing, infighting, batasuna, chuang, superhuman, oldcastle, caucus,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4425 0.1889 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4373 0.1863 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4135 0.1864 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3991 0.1867 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4078 0.1867 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4221 0.1870 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3767 0.1867 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3796 0.1876 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4126 0.1856 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3784 0.1869 sec/batch
# Nearest to have: apl, crayfish, install, monody, already, spectrum, dealings, small,
# Nearest to use: karlovac, circuits, ability, components, interconnected, deadwood, integrated, augmented,
# Nearest to american: comedian, actor, joe, rick, businessman, football, nobel, prize,
# Nearest to up: stumble, trilemma, supper, escorial, motor, yeo, evidentiary, ceasefire,
# Nearest to would: tuition, probabilistic, betsy, mannlicher, germline, ripple, vagina, jumps,
# Nearest to if: any, samples, conversely, simple, man, invariance, bustling, vitally,
# Nearest to when: beneficial, thea, multivariate, readily, openly, cnbc, intolerable, dangerous,
# Nearest to about: skilling, photographic, uqbar, loach, ads, practicality, decadence, inhalation,
# Nearest to older: blessed, squeezes, classicists, kosar, yes, counseling, marva, warmblood,
# Nearest to governor: consular, mumford, assize, senate, queens, provincial, provinces, crown,
# Nearest to heavy: trolley, teamwork, regolith, yellow, pubs, versatility, repair, unbeknownst,
# Nearest to placed: responded, russel, disqualification, prepared, noticeable, simplest, navy, unprofessional,
# Nearest to joseph: planner, mineralogist, vsat, wife, nbs, biographies, alexei, xlii,
# Nearest to discovered: unprofessional, encampments, asteroid, harrisburg, hj, stereotype, woodsman, operant,
# Nearest to quite: manichean, be, uua, asch, mitral, gyatso, ho, penile,
# Nearest to rise: metabolically, picketing, infighting, batasuna, caucus, pulleys, aragonese, oldcastle,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3463 0.1898 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3971 0.1852 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3354 0.1872 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3716 0.1867 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3942 0.1884 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3586 0.1881 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3690 0.1862 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3777 0.1868 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3277 0.1859 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2981 0.1862 sec/batch
# Nearest to have: crayfish, install, apl, pumped, small, germination, already, spectrum,
# Nearest to use: karlovac, integrated, categorize, circuits, components, symbolics, compatibles, interconnected,
# Nearest to american: comedian, actor, joe, businessman, rick, durrell, nobel, football,
# Nearest to up: stumble, trilemma, supper, motor, yeo, escorial, silja, comfortably,
# Nearest to would: probabilistic, tuition, germline, ripple, betsy, vagina, mannlicher, septicemic,
# Nearest to if: any, simple, samples, conversely, man, invariance, xi, tire,
# Nearest to when: thea, beneficial, dangerous, multivariate, openly, cnbc, shiftrows, window,
# Nearest to about: skilling, photographic, uqbar, decadence, agronomy, practicality, emplaced, stasis,
# Nearest to older: blessed, yes, squeezes, classicists, kosar, counseling, warmblood, marva,
# Nearest to governor: consular, assize, mumford, provincial, senate, crown, act, provinces,
# Nearest to heavy: trolley, teamwork, regolith, pubs, versatility, yellow, uranium, unbeknownst,
# Nearest to placed: responded, disqualification, russel, prepared, simplest, noticeable, outlying, unprofessional,
# Nearest to joseph: planner, mineralogist, vsat, nbs, wife, xlii, poems, biographies,
# Nearest to discovered: unprofessional, asteroid, encampments, hj, harrisburg, operant, anac, sasl,
# Nearest to quite: be, manichean, uua, asch, mitral, ho, gyatso, unknowingly,
# Nearest to rise: metabolically, infighting, batasuna, picketing, oldcastle, aragonese, caucus, pulleys,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3488 0.1894 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2769 0.1864 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3699 0.1869 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3737 0.1866 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3643 0.1868 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2676 0.1869 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2542 0.1851 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3017 0.1863 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1999 0.1851 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2852 0.1870 sec/batch
# Nearest to have: crayfish, apl, dealings, install, germination, small, monody, pumped,
# Nearest to use: karlovac, symbolics, categorize, components, integrated, circuits, compatibles, interconnected,
# Nearest to american: comedian, actor, nobel, prize, joe, businessman, durrell, rick,
# Nearest to up: stumble, supper, trilemma, yeo, silja, motor, datagram, escorial,
# Nearest to would: probabilistic, tuition, ripple, mannlicher, septicemic, germline, betsy, couched,
# Nearest to if: any, xi, conversely, man, invariance, samples, simple, gradius,
# Nearest to when: thea, openly, intolerable, shiftrows, objectification, cnbc, grey, dangerous,
# Nearest to about: skilling, photographic, uqbar, loach, inalienable, emplaced, stasis, ads,
# Nearest to older: classicists, warmblood, squeezes, yes, blessed, counseling, kosar, marva,
# Nearest to governor: mumford, consular, assize, provincial, crown, senate, queens, act,
# Nearest to heavy: versatility, trolley, regolith, teamwork, pubs, yellow, unbeknownst, uranium,
# Nearest to placed: responded, disqualification, prepared, russel, simplest, genosha, belew, numb,
# Nearest to joseph: planner, mineralogist, vsat, nbs, wife, xlii, fracturing, biographies,
# Nearest to discovered: asteroid, unprofessional, encampments, harrisburg, hj, anac, operant, jambalaya,
# Nearest to quite: uua, manichean, be, asch, gyatso, mitral, ho, penile,
# Nearest to rise: metabolically, infighting, picketing, oldcastle, batasuna, aragonese, caucus, fledged,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2755 0.1883 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2630 0.1861 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3309 0.0929 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2186 0.1864 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2164 0.1856 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2210 0.1870 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1851 0.1856 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1895 0.1862 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2060 0.1868 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1548 0.1854 sec/batch
# Nearest to have: crayfish, install, apl, small, germination, monody, already, dealings,
# Nearest to use: karlovac, compatibles, symbolics, interconnected, circuits, lsi, components, texts,
# Nearest to american: comedian, nobel, actor, businessman, durrell, concordant, joe, thelma,
# Nearest to up: trilemma, stumble, supper, silja, because, datagram, ambience, perro,
# Nearest to would: probabilistic, tuition, ripple, lacquer, septicemic, clear, germline, mannlicher,
# Nearest to if: any, xi, man, invariance, conversely, saying, gradius, ovaries,
# Nearest to when: shiftrows, openly, objectification, intolerable, thea, neck, dangerous, window,
# Nearest to about: skilling, photographic, uqbar, decadence, agronomy, inalienable, summers, loach,
# Nearest to older: warmblood, squeezes, classicists, females, median, counseling, kosar, blessed,
# Nearest to governor: assize, mumford, consular, act, senate, provincial, taoiseach, crown,
# Nearest to heavy: versatility, teamwork, trolley, pubs, regolith, yellow, unbeknownst, uranium,
# Nearest to placed: responded, disqualification, prepared, russel, genosha, simplest, numb, outlying,
# Nearest to joseph: planner, mineralogist, vsat, biographies, wife, xlii, nbs, rome,
# Nearest to discovered: asteroid, unprofessional, encampments, harrisburg, hj, anac, operant, reverend,
# Nearest to quite: be, uua, manichean, mitral, asch, ho, penile, gyatso,
# Nearest to rise: metabolically, infighting, picketing, oldcastle, batasuna, caucus, innovation, aragonese,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2206 0.1882 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1987 0.1875 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1940 0.1882 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1205 0.1868 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1542 0.1873 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1354 0.1863 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1006 0.1856 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1454 0.1984 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1759 0.2019 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1796 0.1882 sec/batch
# Nearest to have: crayfish, install, small, apl, already, germination, dealings, pumped,
# Nearest to use: karlovac, texts, categorize, interconnected, compatibles, ease, deadwood, symbolics,
# Nearest to american: concordant, comedian, businessman, nobel, employee, thelma, actor, universitet,
# Nearest to up: stumble, trilemma, silja, datagram, supper, sequentially, because, ambience,
# Nearest to would: probabilistic, tuition, septicemic, ripple, germline, lacquer, vagina, betsy,
# Nearest to if: any, xi, invariance, man, saying, conversely, ovaries, gradius,
# Nearest to when: shiftrows, objectification, window, multivariate, intolerable, neck, dangerous, openly,
# Nearest to about: skilling, agronomy, emplaced, photographic, decadence, uqbar, stasis, loach,
# Nearest to older: median, females, household, warmblood, squeezes, counseling, classicists, blessed,
# Nearest to governor: assize, consular, mumford, act, senate, provincial, taoiseach, legislative,
# Nearest to heavy: pubs, trolley, teamwork, versatility, regolith, unbeknownst, uranium, repair,
# Nearest to placed: responded, disqualification, prepared, simplest, genosha, russel, noticeable, an,
# Nearest to joseph: planner, mineralogist, vsat, rashi, nbs, uvs, xlii, biographies,
# Nearest to discovered: asteroid, encampments, unprofessional, hj, anac, harrisburg, reciprocating, operant,
# Nearest to quite: be, uua, manichean, mitral, penile, ho, gyatso, asch,
# Nearest to rise: metabolically, picketing, infighting, batasuna, oldcastle, caucus, innovation, prehistoric,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1781 0.1898 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2016 0.1890 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1621 0.1880 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1435 0.1871 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1662 0.1881 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1625 0.1874 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1742 0.1882 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1253 0.1884 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1274 0.1888 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1291 0.1886 sec/batch
# Nearest to have: install, small, crayfish, apl, already, monody, dealings, pumped,
# Nearest to use: texts, karlovac, compatibles, categorize, symbolics, interconnected, cummins, deadwood,
# Nearest to american: comedian, actor, businessman, nobel, concordant, durrell, prize, thelma,
# Nearest to up: stumble, trilemma, silja, datagram, motor, escapees, mtu, evidentiary,
# Nearest to would: probabilistic, tuition, ripple, septicemic, germline, clear, lacquer, inquire,
# Nearest to if: any, xi, invariance, man, conversely, tire, saying, gradius,
# Nearest to when: shiftrows, multivariate, objectification, window, openly, thea, intolerable, hitherto,
# Nearest to about: emplaced, photographic, agronomy, ads, uqbar, skilling, practicality, decadence,
# Nearest to older: females, median, household, blessed, warmblood, squeezes, classicists, kosar,
# Nearest to governor: assize, consular, mumford, act, senate, provincial, taoiseach, crown,
# Nearest to heavy: pubs, repair, regolith, trolley, unbeknownst, uranium, versatility, teamwork,
# Nearest to placed: responded, disqualification, genosha, prepared, outlying, belew, simplest, noticeable,
# Nearest to joseph: planner, mineralogist, biographies, vsat, rashi, reinhold, nbs, soderbergh,
# Nearest to discovered: asteroid, encampments, unprofessional, migration, harrisburg, hj, sources, anac,
# Nearest to quite: be, uua, manichean, mitral, ho, penile, codify, gyatso,
# Nearest to rise: metabolically, infighting, picketing, oldcastle, caucus, batasuna, innovation, aragonese,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2063 0.1920 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1794 0.1876 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1530 0.1873 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1681 0.1912 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1074 0.2081 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0965 0.2055 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1283 0.2025 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0989 0.1912 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1819 0.1898 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1987 0.1921 sec/batch
# Nearest to have: install, apl, small, already, dealings, crayfish, indulgent, breeders,
# Nearest to use: texts, karlovac, cummins, compatibles, interconnected, symbolics, categorize, deadwood,
# Nearest to american: comedian, actor, businessman, nobel, prize, durrell, thelma, joe,
# Nearest to up: stumble, silja, trilemma, escapees, pdci, datagram, marines, yeo,
# Nearest to would: probabilistic, tuition, ripple, septicemic, betsy, clear, festal, germline,
# Nearest to if: any, xi, invariance, conversely, man, saying, gradius, tire,
# Nearest to when: shiftrows, thea, objectification, openly, multivariate, hitherto, window, intolerable,
# Nearest to about: skilling, emplaced, decadence, stasis, photographic, uqbar, agronomy, lightness,
# Nearest to older: median, females, blessed, household, warmblood, classicists, yes, kosar,
# Nearest to governor: assize, mumford, consular, act, crown, ceremonial, provincial, taoiseach,
# Nearest to heavy: pubs, repair, regolith, versatility, trolley, unbeknownst, dingo, teamwork,
# Nearest to placed: responded, genosha, disqualification, prepared, outlying, noticeable, simplest, treasure,
# Nearest to joseph: planner, mineralogist, rashi, reinhold, biographies, soderbergh, els, xlii,
# Nearest to discovered: asteroid, encampments, unprofessional, migration, hj, hendrik, harrisburg, sources,
# Nearest to quite: be, uua, manichean, mitral, ho, penile, codify, rheumatoid,
# Nearest to rise: metabolically, infighting, oldcastle, picketing, aragonese, caucus, harpers, batasuna,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2061 0.1917 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1125 0.1888 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0913 0.1894 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1231 0.1881 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0020 0.1885 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0994 0.1885 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1141 0.1890 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0868 0.1889 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1479 0.0477 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1063 0.1880 sec/batch
# Nearest to have: install, small, already, indulgent, apl, crayfish, breeders, pumped,
# Nearest to use: texts, compatibles, interconnected, karlovac, cummins, rifles, symbolics, categorize,
# Nearest to american: comedian, actor, businessman, prize, concordant, nobel, durrell, football,
# Nearest to up: trilemma, stumble, silja, escapees, datagram, pdci, mtu, motor,
# Nearest to would: probabilistic, ripple, clear, tuition, germline, septicemic, lacquer, torrid,
# Nearest to if: any, xi, invariance, conversely, saying, man, ovaries, impulse,
# Nearest to when: shiftrows, objectification, multivariate, window, hitherto, openly, thea, intolerable,
# Nearest to about: emplaced, agronomy, yahoo, ads, skilling, stasis, summers, lightness,
# Nearest to older: median, household, females, warmblood, kosar, classicists, counseling, blessed,
# Nearest to governor: assize, mumford, consular, ceremonial, provincial, crown, act, taoiseach,
# Nearest to heavy: pubs, versatility, repair, regolith, unbeknownst, dingo, trolley, teamwork,
# Nearest to placed: responded, genosha, simplest, disqualification, outlying, prepared, noticeable, entrapped,
# Nearest to joseph: planner, mineralogist, biographies, reinhold, rashi, soderbergh, els, vsat,
# Nearest to discovered: asteroid, encampments, unprofessional, orbited, hj, radioactive, hendrik, sources,
# Nearest to quite: be, uua, penile, manichean, mitral, ho, rheumatoid, codify,
# Nearest to rise: metabolically, infighting, oldcastle, picketing, innovation, aragonese, caucus, harpers,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0580 0.1916 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0748 0.1891 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0605 0.1893 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0165 0.1888 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0601 0.1920 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0070 0.1922 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0676 0.1885 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0680 0.1876 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0670 0.1873 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0056 0.1881 sec/batch
# Nearest to have: small, install, indulgent, crayfish, already, sparks, apl, breeders,
# Nearest to use: texts, compatibles, interconnected, karlovac, cummins, categorize, simulators, symbolics,
# Nearest to american: comedian, actor, businessman, concordant, nobel, prize, joe, thelma,
# Nearest to up: trilemma, stumble, silja, escapees, pdci, truetype, datagram, evidentiary,
# Nearest to would: probabilistic, ripple, tuition, lacquer, germline, clear, vagina, bhp,
# Nearest to if: any, conversely, invariance, man, saying, xi, ovaries, streak,
# Nearest to when: shiftrows, objectification, window, not, taoiseach, multivariate, openly, crafting,
# Nearest to about: agronomy, emplaced, lightness, summers, yahoo, stasis, inflate, skilling,
# Nearest to older: median, household, females, warmblood, classicists, kosar, counseling, squeezes,
# Nearest to governor: assize, consular, act, mumford, ceremonial, senate, crown, provincial,
# Nearest to heavy: pubs, versatility, repair, cormack, regolith, dingo, trolley, teamwork,
# Nearest to placed: responded, simplest, genosha, outlying, prepared, disqualification, noticeable, bust,
# Nearest to joseph: planner, mineralogist, biographies, rashi, reinhold, vsat, uvs, els,
# Nearest to discovered: asteroid, encampments, unprofessional, orbited, anac, sasl, migration, interleaved,
# Nearest to quite: be, uua, penile, ho, mitral, manichean, nubians, codify,
# Nearest to rise: metabolically, infighting, oldcastle, innovation, picketing, caucus, harpers, batasuna,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0052 0.1900 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9774 0.1886 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9873 0.1873 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0131 0.1888 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0134 0.2027 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9968 0.2007 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0101 0.1957 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0759 0.1979 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0254 0.1990 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0278 0.1975 sec/batch
# Nearest to have: small, already, indulgent, pumped, install, are, merwara, apl,
# Nearest to use: texts, cummins, compatibles, karlovac, interconnected, categorize, simulators, deadwood,
# Nearest to american: comedian, actor, businessman, prize, nobel, rick, concordant, thelma,
# Nearest to up: stumble, escapees, trilemma, silja, truetype, datagram, ambience, mtu,
# Nearest to would: probabilistic, ripple, germline, tuition, clear, vagina, septicemic, torrid,
# Nearest to if: any, invariance, conversely, man, saying, xi, ovaries, tire,
# Nearest to when: shiftrows, objectification, window, not, multivariate, intolerable, suitably, crafting,
# Nearest to about: agronomy, skilling, emplaced, ads, yahoo, stasis, lightness, photographic,
# Nearest to older: median, household, females, warmblood, classicists, kosar, counseling, age,
# Nearest to governor: assize, consular, mumford, act, crown, ceremonial, taoiseach, provincial,
# Nearest to heavy: pubs, repair, regolith, cormack, dingo, versatility, trolley, collapsing,
# Nearest to placed: responded, simplest, prepared, noticeable, genosha, outlying, bust, numb,
# Nearest to joseph: planner, biographies, uvs, rashi, vsat, mineralogist, soderbergh, remarks,
# Nearest to discovered: asteroid, encampments, orbited, unprofessional, sources, hendrik, interleaved, sasl,
# Nearest to quite: be, uua, penile, mitral, ho, manichean, codify, nubians,
# Nearest to rise: metabolically, infighting, oldcastle, picketing, innovation, caucus, gelatinous, truest,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0242 0.1970 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0265 0.1918 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0583 0.1923 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9941 0.1893 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0303 0.1883 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0088 0.1914 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0396 0.1888 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0396 0.1891 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0806 0.1866 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0522 0.1877 sec/batch
# Nearest to have: small, already, indulgent, merwara, install, pumped, crayfish, them,
# Nearest to use: texts, cummins, compatibles, simulators, ftc, karlovac, categorize, interconnected,
# Nearest to american: actor, comedian, businessman, prize, concordant, nobel, joe, rick,
# Nearest to up: escapees, trilemma, stumble, silja, vanishing, mtu, playlist, truetype,
# Nearest to would: probabilistic, festal, inquire, clear, tuition, ripple, germline, septicemic,
# Nearest to if: any, conversely, man, saying, invariance, xi, streak, ovaries,
# Nearest to when: objectification, shiftrows, window, not, duchies, multivariate, taoiseach, hitherto,
# Nearest to about: skilling, stasis, lightness, ads, emplaced, agronomy, yahoo, decadence,
# Nearest to older: median, females, household, warmblood, classicists, counseling, age, families,
# Nearest to governor: assize, consular, crown, ceremonial, mumford, act, senate, taoiseach,
# Nearest to heavy: pubs, collapsing, versatility, cormack, repair, regolith, wicb, unbeknownst,
# Nearest to placed: responded, simplest, genosha, outlying, noticeable, treasure, disqualification, prepared,
# Nearest to joseph: planner, mineralogist, biographies, reinhold, vsat, uvs, soderbergh, rashi,
# Nearest to discovered: asteroid, encampments, orbited, migration, unprofessional, hendrik, sources, explored,
# Nearest to quite: be, uua, penile, ho, codify, manichean, mitral, pole,
# Nearest to rise: metabolically, infighting, oldcastle, harpers, picketing, caucus, innovation, colson,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0122 0.1924 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9885 0.1872 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0140 0.1866 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0407 0.1843 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0668 0.1846 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0956 0.1836 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0705 0.1851 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0178 0.1830 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9798 0.1839 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0251 0.1836 sec/batch
# Nearest to have: already, small, indulgent, install, crayfish, apl, sparks, scheme,
# Nearest to use: texts, cummins, ftc, karlovac, simulators, compatibles, interconnected, corolla,
# Nearest to american: actor, comedian, prize, businessman, nobel, concordant, alves, joe,
# Nearest to up: escapees, stumble, silja, vanishing, trilemma, datagram, mtu, playlist,
# Nearest to would: probabilistic, ripple, clear, torrid, lacquer, septicemic, festal, vagina,
# Nearest to if: any, invariance, conversely, saying, man, xi, contractive, adic,
# Nearest to when: shiftrows, objectification, window, not, duchies, crafting, tirith, multivariate,
# Nearest to about: skilling, lightness, stasis, emplaced, yahoo, decadence, ads, interglacial,
# Nearest to older: median, females, household, warmblood, classicists, families, age, counseling,
# Nearest to governor: assize, consular, mumford, ceremonial, crown, act, senate, tocqueville,
# Nearest to heavy: pubs, repair, collapsing, regolith, versatility, cormack, unbeknownst, dingo,
# Nearest to placed: simplest, responded, genosha, outlying, an, prepared, entrapped, bust,
# Nearest to joseph: planner, mineralogist, biographies, remarks, reinhold, vsat, veneziano, uvs,
# Nearest to discovered: asteroid, orbited, encampments, hendrik, unprofessional, explored, migration, holst,
# Nearest to quite: be, uua, penile, codify, manichean, mitral, falsification, ho,
# Nearest to rise: metabolically, infighting, oldcastle, caucus, innovation, harpers, colson, picketing,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9215 0.1870 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0249 0.1851 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9922 0.1904 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0044 0.1894 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0414 0.1850 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9986 0.1856 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9699 0.1845 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9425 0.1843 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0029 0.1849 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9656 0.1859 sec/batch
# Nearest to have: already, small, indulgent, install, bureaucratic, sparks, breeders, believe,
# Nearest to use: texts, cummins, rifles, compatibles, karlovac, ftc, interconnected, clockrate,
# Nearest to american: comedian, actor, businessman, prize, nobel, alves, rick, coen,
# Nearest to up: escapees, stumble, trilemma, vanishing, silja, truetype, heroquest, mtu,
# Nearest to would: probabilistic, ripple, clear, torrid, festal, germline, then, lacquer,
# Nearest to if: any, invariance, conversely, saying, man, xi, ovaries, codomain,
# Nearest to when: window, shiftrows, not, duchies, objectification, olympians, crafting, taoiseach,
# Nearest to about: skilling, stasis, lightness, emplaced, yahoo, interglacial, agronomy, copernicanism,
# Nearest to older: median, females, household, warmblood, families, classicists, below, kosar,
# Nearest to governor: assize, consular, mumford, ceremonial, crown, act, muskie, tocqueville,
# Nearest to heavy: pubs, repair, collapsing, cormack, gelre, regolith, versatility, dingo,
# Nearest to placed: simplest, responded, genosha, outlying, bust, treasure, entrapped, noticeable,
# Nearest to joseph: planner, mineralogist, biographies, reinhold, remarks, veneziano, els, vsat,
# Nearest to discovered: asteroid, encampments, orbited, explored, unprofessional, migration, holst, hendrik,
# Nearest to quite: be, penile, uua, codify, manichean, mitral, falsification, ho,
# Nearest to rise: metabolically, infighting, oldcastle, picketing, colson, innovation, caucus, harpers,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9470 0.1948 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9028 0.1920 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9765 0.1855 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9954 0.1862 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9960 0.1863 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9576 0.1879 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8640 0.1864 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9034 0.1863 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8577 0.1860 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9511 0.1906 sec/batch
# Nearest to have: small, already, indulgent, are, breeders, pumped, sparks, exception,
# Nearest to use: cummins, texts, karlovac, is, interconnected, compatibles, ftc, rifles,
# Nearest to american: comedian, actor, concordant, businessman, prize, nobel, islander, coen,
# Nearest to up: escapees, stumble, vanishing, truetype, silja, moksha, trilemma, ambience,
# Nearest to would: probabilistic, clear, fein, ripple, torrid, festal, then, they,
# Nearest to if: any, invariance, saying, conversely, man, codomain, ovaries, contractive,
# Nearest to when: window, shiftrows, objectification, not, crafting, olympians, duchies, tirith,
# Nearest to about: lightness, stasis, emplaced, ads, interglacial, agronomy, lichens, yahoo,
# Nearest to older: median, females, household, warmblood, families, classicists, counseling, below,
# Nearest to governor: assize, consular, ceremonial, act, mumford, crown, muskie, tocqueville,
# Nearest to heavy: pubs, collapsing, repair, regolith, cormack, battalions, wicb, gelre,
# Nearest to placed: simplest, responded, genosha, outlying, bust, entrapped, treasure, an,
# Nearest to joseph: planner, uvs, biographies, mineralogist, reinhold, nbs, remarks, veneziano,
# Nearest to discovered: asteroid, orbited, encampments, explored, migration, unprofessional, hendrik, tops,
# Nearest to quite: be, penile, uua, ho, codify, manichean, mitral, falsification,
# Nearest to rise: metabolically, infighting, oldcastle, innovation, caucus, colson, intricacy, picketing,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9659 0.1895 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9568 0.1879 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9389 0.1877 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0113 0.1880 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9660 0.1870 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9329 0.1872 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9597 0.1872 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9739 0.1891 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9602 0.1877 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9600 0.1896 sec/batch
# Nearest to have: small, already, indulgent, install, breeders, believe, nonetheless, are,
# Nearest to use: cummins, texts, ftc, is, mantra, karlovac, clockrate, interconnected,
# Nearest to american: actor, comedian, businessman, prize, nobel, coen, rick, alves,
# Nearest to up: escapees, vanishing, stumble, truetype, silja, mtu, playlist, magnetron,
# Nearest to would: probabilistic, torrid, ripple, betsy, clear, festal, then, herut,
# Nearest to if: any, invariance, conversely, man, saying, feels, tire, gradius,
# Nearest to when: not, shiftrows, window, objectification, olympians, multivariate, pitfall, crafting,
# Nearest to about: lightness, yahoo, stasis, ads, skilling, fads, copernicanism, emplaced,
# Nearest to older: median, household, females, warmblood, families, below, present, classicists,
# Nearest to governor: assize, consular, crown, ceremonial, mumford, act, muskie, tocqueville,
# Nearest to heavy: pubs, repair, collapsing, regolith, wicb, bombarding, gelre, cormack,
# Nearest to placed: simplest, responded, bust, genosha, outlying, treasure, entrapped, apostles,
# Nearest to joseph: planner, reinhold, decomposition, mineralogist, biographies, remarks, uvs, els,
# Nearest to discovered: asteroid, orbited, encampments, explored, migration, tops, hendrik, flare,
# Nearest to quite: be, penile, uua, codify, ho, mitral, falsification, manichean,
# Nearest to rise: metabolically, infighting, oldcastle, innovation, caucus, colson, picketing, intricacy,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9828 0.1909 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9480 0.1885 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9059 0.1877 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9620 0.1875 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9617 0.1878 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9730 0.1878 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9395 0.1887 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9410 0.1892 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9135 0.1884 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9869 0.1883 sec/batch
# Nearest to have: small, already, indulgent, are, believe, install, nonetheless, breeders,
# Nearest to use: cummins, ftc, texts, is, karlovac, clockrate, compatibles, rifles,
# Nearest to american: actor, comedian, prize, businessman, nobel, coen, lisle, alves,
# Nearest to up: escapees, vanishing, mtu, truetype, silja, stumble, datagram, magnetron,
# Nearest to would: probabilistic, clear, ripple, torrid, fein, festal, floundered, herut,
# Nearest to if: any, invariance, conversely, saying, contractive, man, codomain, feels,
# Nearest to when: not, shiftrows, window, objectification, duchies, tirith, pitfall, looptail,
# Nearest to about: lightness, yahoo, stasis, fads, ads, copernicanism, skilling, summary,
# Nearest to older: median, females, household, warmblood, families, classicists, present, counseling,
# ...
# Nearest to american: actor, united, comedian, association, concordant, songwriters, coen, springfield,
# Nearest to up: escapees, vanishing, pentagons, fourteen, semipalatinsk, and, to, an,
# Nearest to would: they, time, do, then, probabilistic, torrid, ques, timepieces,
# Nearest to if: any, conversely, contractive, invariance, arithmeticae, malachi, pastures, escaping,
# Nearest to when: not, to, the, that, but, window, also, looptail,
# Nearest to about: fads, by, that, on, is, less, regarding, there,
# Nearest to older: median, females, household, below, age, size, families, fewer,
# Nearest to governor: hyderabad, mumford, ceremonial, harland, muskie, assize, fiendish, sident,
# Nearest to heavy: wicb, cormack, maersk, metal, khomeini, axl, desktop, anderson,
# Nearest to placed: responded, simplest, outlying, bust, entrapped, apostles, pangolins, employee,
# Nearest to joseph: remarks, departs, els, enjoys, rashi, aristides, biographies, theosophy,
# Nearest to discovered: encampments, shoemaker, asteroid, explored, sizeable, implanted, discoverer, fabricating,
# Nearest to quite: be, penile, meticulously, prequels, fortran, ho, falsification, although,
# Nearest to rise: metabolically, infighting, caucus, colson, writeups, bubbles, ode, forgiving,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7629 0.1900 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8117 0.1865 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8138 0.1865 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8189 0.1885 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7946 0.1870 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8393 0.1876 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7959 0.1853 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7435 0.1865 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8345 0.1877 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8355 0.1859 sec/batch
# Nearest to have: are, has, other, small, such, they, there, only,
# Nearest to use: cummins, ftc, used, unlike, automatic, texts, bbci, widely,
# Nearest to american: actor, united, concordant, prize, association, songwriters, comedian, vectorborne,
# Nearest to up: escapees, vanishing, pentagons, semipalatinsk, fourteen, is, mtu, berliner,
# Nearest to would: do, time, they, then, probabilistic, that, to, ques,
# Nearest to if: conversely, any, contractive, invariance, arithmeticae, malachi, escaping, saying,
# Nearest to when: to, not, the, that, also, window, is, it,
# Nearest to about: fads, that, regarding, and, on, should, there, to,
# Nearest to older: median, females, household, below, age, families, size, present,
# Nearest to governor: ceremonial, hyderabad, assize, mumford, muskie, statewide, harland, fiendish,
# Nearest to heavy: wicb, maersk, cormack, helmuth, printers, metal, desktop, anderson,
# Nearest to placed: responded, simplest, outlying, entrapped, apostles, bust, dl, pangolins,
# Nearest to joseph: remarks, departs, els, thinks, biographies, rashi, aristides, accumulated,
# Nearest to discovered: encampments, shoemaker, explored, asteroid, pontius, discoverer, orbited, holst,
# Nearest to quite: be, penile, fortran, meticulously, although, prequels, ho, generalities,
# Nearest to rise: metabolically, infighting, colson, bubbles, caucus, wannsee, activity, forgiving,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8108 0.1895 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7968 0.1858 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7648 0.1869 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7673 0.1860 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8818 0.1874 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7849 0.1872 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9021 0.1885 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8528 0.1881 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8194 0.1868 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7247 0.1879 sec/batch
# Nearest to have: are, has, other, such, small, they, there, be,
# Nearest to use: cummins, used, ftc, unlike, is, automatic, bbci, not,
# Nearest to american: actor, united, prize, comedian, concordant, association, promote, songwriters,
# Nearest to up: escapees, one, semipalatinsk, vanishing, pentagons, fourteen, berliner, to,
# Nearest to would: they, do, ques, then, to, probabilistic, time, that,
# Nearest to if: conversely, any, arithmeticae, contractive, invariance, malachi, escaping, then,
# Nearest to when: to, the, not, also, it, window, in, is,
# Nearest to about: fads, by, that, on, regarding, zero, to, and,
# Nearest to older: median, females, household, age, below, families, size, householder,
# Nearest to governor: ceremonial, hyderabad, mumford, harland, muskie, assize, tocqueville, sident,
# Nearest to heavy: wicb, cormack, maersk, helmuth, anderson, printers, khomeini, cc,
# Nearest to placed: responded, simplest, outlying, entrapped, apostles, bust, pangolins, dl,
# Nearest to joseph: remarks, departs, els, biographies, thinks, rashi, aristides, reinhold,
# Nearest to discovered: encampments, explored, holst, pontius, shoemaker, asteroid, occasioned, rard,
# Nearest to quite: be, penile, fortran, meticulously, prequels, ho, falsification, generalities,
# Nearest to rise: metabolically, infighting, caucus, colson, bubbles, wannsee, writeups, activity,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7415 0.1865 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7569 0.1854 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7442 0.1869 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8146 0.1877 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7873 0.1866 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8235 0.1868 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8089 0.1401 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8161 0.1865 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7599 0.1846 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8321 0.1870 sec/batch
# Nearest to have: are, has, other, such, they, small, there, be,
# Nearest to use: used, cummins, ftc, widely, unlike, is, automatic, also,
# Nearest to american: actor, united, prize, songwriters, comedian, concordant, vectorborne, association,
# Nearest to up: escapees, semipalatinsk, vanishing, to, pentagons, call, fourteen, is,
# Nearest to would: they, do, to, time, that, torrid, then, probabilistic,
# Nearest to if: conversely, any, invariance, malachi, contractive, escaping, arithmeticae, saying,
# Nearest to when: to, the, not, but, it, was, also, in,
# Nearest to about: by, fads, from, on, that, is, to, regarding,
# Nearest to older: median, females, household, age, below, families, size, householder,
# Nearest to governor: ceremonial, hyderabad, mumford, harland, repugnant, muskie, assize, tocqueville,
# Nearest to heavy: wicb, cormack, maersk, anderson, helmuth, khomeini, printers, axl,
# Nearest to placed: responded, simplest, outlying, entrapped, bust, apostles, annabella, pangolins,
# Nearest to joseph: departs, remarks, aristides, els, biographies, thinks, swieten, accumulated,
# Nearest to discovered: encampments, implanted, pontius, asteroid, explored, rard, shoemaker, holst,
# Nearest to quite: be, penile, fortran, although, codify, ho, meticulously, prequels,
# Nearest to rise: metabolically, infighting, colson, bubbles, caucus, wannsee, writeups, activity,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7424 0.1884 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7649 0.1861 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7129 0.1873 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8033 0.1861 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7963 0.1862 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8101 0.1849 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8041 0.1860 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6950 0.1866 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7793 0.1862 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.6860 0.1847 sec/batch
# Nearest to have: are, has, other, they, small, such, only, there,
# Nearest to use: used, cummins, is, widely, ftc, in, form, unlike,
# Nearest to american: united, actor, concordant, association, promote, songwriters, vectorborne, aaa,
# Nearest to up: to, vanishing, pentagons, escapees, an, semipalatinsk, fourteen, is,
# Nearest to would: they, do, time, then, to, that, torrid, ques,
# Nearest to if: any, conversely, contractive, invariance, malachi, escaping, arithmeticae, is,
# Nearest to when: to, not, the, also, that, but, it, is,
# Nearest to about: fads, from, on, by, regarding, that, is, less,
# Nearest to older: median, females, household, age, below, families, size, householder,
# Nearest to governor: hyderabad, ceremonial, repugnant, mumford, harland, behalf, muskie, sident,
# Nearest to heavy: wicb, maersk, cormack, anderson, helmuth, printers, metal, pubs,
# Nearest to placed: simplest, responded, outlying, bust, pangolins, dl, entrapped, an,
# Nearest to joseph: departs, remarks, thinks, latter, swieten, els, accumulated, biographies,
# Nearest to discovered: encampments, shoemaker, explored, fabricating, pontius, sizeable, asteroid, discoverer,
# Nearest to quite: be, penile, fortran, although, meticulously, ho, generalities, prequels,
# Nearest to rise: metabolically, infighting, colson, bubbles, caucus, writeups, activity, wannsee,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7200 0.1891 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7612 0.1864 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7833 0.1859 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7636 0.1878 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7545 0.1857 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8509 0.1926 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7858 0.2043 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7313 0.2078 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7967 0.1957 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7741 0.1952 sec/batch
# Nearest to have: are, other, has, they, small, such, only, with,
# Nearest to use: used, cummins, ftc, is, widely, unlike, to, in,
# Nearest to american: actor, united, association, songwriters, concordant, americans, vectorborne, comedian,
# Nearest to up: to, vanishing, semipalatinsk, pentagons, an, escapees, fourteen, is,
# Nearest to would: they, do, time, demilitarization, so, had, then, torrid,
# Nearest to if: conversely, any, invariance, malachi, escaping, contractive, arithmeticae, pastures,
# Nearest to when: to, not, the, also, window, in, it, that,
# Nearest to about: fads, from, regarding, on, and, yahoo, that, detailed,
# Nearest to older: median, females, household, below, age, size, families, present,
# Nearest to governor: hyderabad, ceremonial, harland, behalf, repugnant, fiendish, muskie, mumford,
# Nearest to heavy: wicb, cormack, maersk, anderson, helmuth, printers, pubs, metal,
# Nearest to placed: responded, simplest, outlying, pangolins, an, entrapped, bust, conductive,
# Nearest to joseph: remarks, departs, els, thinks, biographies, accumulated, aristides, enjoys,
# Nearest to discovered: encampments, pontius, shoemaker, discoverer, explored, implanted, fabricating, fontana,
# Nearest to quite: be, penile, fortran, although, prequels, meticulously, ho, codify,
# Nearest to rise: metabolically, writeups, colson, caucus, activity, bubbles, infighting, wannsee,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7580 0.1940 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8202 0.1948 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7946 0.1907 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7799 0.1892 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8181 0.1887 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7750 0.1906 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8161 0.1891 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7422 0.1893 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7638 0.1896 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7411 0.1879 sec/batch
# Nearest to have: are, other, has, they, small, there, such, with,
# Nearest to use: used, is, cummins, unlike, ftc, to, or, form,
# Nearest to american: united, actor, association, americans, songwriters, promote, concordant, vectorborne,
# Nearest to up: one, to, semipalatinsk, vanishing, pentagons, an, escapees, destined,
# Nearest to would: they, do, that, to, so, time, could, start,
# Nearest to if: any, conversely, invariance, malachi, contractive, is, escaping, then,
# Nearest to when: to, not, the, is, in, also, that, it,
# Nearest to about: that, fads, and, on, from, regarding, to, is,
# Nearest to older: median, females, household, age, below, present, size, families,
# Nearest to governor: ceremonial, hyderabad, behalf, repugnant, sident, fiendish, assize, harland,
# Nearest to heavy: wicb, maersk, anderson, cormack, metal, helmuth, cc, printers,
# Nearest to placed: simplest, responded, pangolins, an, outlying, apostles, entrapped, dl,
# Nearest to joseph: remarks, departs, aristides, els, biographies, accumulated, thinks, swieten,
# Nearest to discovered: encampments, explored, discoverer, pontius, shoemaker, implanted, vaccine, isolated,
# Nearest to quite: be, penile, fortran, meticulously, although, ho, codify, prequels,
# Nearest to rise: metabolically, writeups, wannsee, bubbles, activity, colson, caucus, infighting,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8353 0.1915 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7663 0.1900 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9144 0.1897 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8055 0.1896 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8276 0.1880 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7553 0.1897 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.6907 0.1878 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8108 0.1889 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6879 0.1903 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7865 0.1916 sec/batch
# Nearest to have: are, has, other, they, small, there, such, with,
# Nearest to use: used, unlike, ftc, is, cummins, to, automatic, also,
# Nearest to american: actor, comedian, united, songwriters, prize, association, americans, ronan,
# Nearest to up: to, pentagons, vanishing, an, semipalatinsk, escapees, fourteen, destined,
# Nearest to would: they, do, that, to, so, had, time, probabilistic,
# Nearest to if: conversely, invariance, contractive, any, arithmeticae, malachi, diagonal, then,
# Nearest to when: to, also, not, that, the, but, in, it,
# Nearest to about: and, that, to, by, fads, from, is, on,
# Nearest to older: median, females, household, age, below, families, present, size,
# Nearest to governor: ceremonial, hyderabad, planters, behalf, harland, mumford, sident, assize,
# Nearest to heavy: maersk, wicb, cormack, anderson, helmuth, metal, printers, cc,
# Nearest to placed: simplest, responded, pangolins, an, outlying, dl, employee, bust,
# Nearest to joseph: departs, remarks, aristides, biographies, accumulated, els, rashi, reinhold,
# Nearest to discovered: encampments, explored, pontius, shoemaker, discoverer, implanted, fabricating, vaccine,
# Nearest to quite: be, penile, fortran, prequels, meticulously, fingernails, although, ho,
# Nearest to rise: metabolically, wannsee, writeups, colson, bubbles, activity, infighting, xiamen,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7833 0.1930 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7675 0.1885 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
